# %%
import pandas as pd

# %%
df=pd.read_csv('nexon_api_raw.csv')

# %%
df.content[1054]
# Out:
# '{\n  "date": null,\n  "character_hexa_core_equipment": [\n    {\n      "hexa_core_name": "레퀴엠",\n      "hexa_core_level": 30,\n      "hexa_core_type": "스킬 코어",\n      "linked_skill": [\n        {\n          "hexa_skill_id": "레퀴엠"\n        }\n      ]\n    },\n    {\n      "hexa_core_name": "레이지본 데어데빌",\n      "hexa_core_level": 30,\n      "hexa_core_type": "스킬 코어",\n      "linked_skill": [\n        {\n          "hexa_skill_id": "레이지본 데어데빌"\n        }\n      ]\n    },\n    {\n      "hexa_core_name": "실드 체이싱 VI",\n      "hexa_core_level": 30,\n      "hexa_core_type": "마스터리 코어",\n      "linked_skill": [\n        {\n          "hexa_skill_id": "실드 체이싱 VI"\n        }\n      ]\n    },\n    {\n      "hexa_core_name": "익시드 : 엑스큐션 VI",\n      "hexa_core_level": 30,\n      "hexa_core_type": "마스터리 코어",\n      "linked_skill": [\n        {\n          "hexa_skill_id": "익시드 : 엑스큐션 VI"\n        }\n      ]\n    },\n    {\n      "hexa_core_name": "익시드 : 문라이트 슬래시 VI/오버맥시마이징 익시드",\n      "hexa_core_level
# ...
